# %%
import tiktoken

# %%
enc = tiktoken.get_encoding("o200k_base")

c = enc.encode("hello world")
c
# Out:
# [24912, 2375]

# %%
enc.decode(c)
# Out:
# 'hello world'

# %%
enc.encode(" ")
# Out:
# [220]

# %%
enc.decode([-220])
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 enc.decode([-220])
#
# File /opt/anaconda3/envs/MT-GenRKM/lib/python3.12/site-packages/tiktoken/core.py:284, in Encoding.decode(self, tokens, errors)
#     272 def decode(self, tokens: Sequence[int], errors: str = "replace") -> str:
#     273     """Decodes a list of tokens into a string.
#     274
#     275     WARNING: the default behaviour of this function is lossy, since decoded bytes are not
#    (...)    282     ```
#     283     """
# --> 284     return self._core_bpe.decode_bytes(tokens).decode("utf-8", errors=errors)
#
# OverflowError: out of range integral type conversion attempted
